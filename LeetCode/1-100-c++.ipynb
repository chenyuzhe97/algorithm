# %%
/%
5.最长回文子串
给你一个字符串 s，找到 s 中最长的回文子串。
给你一个字符串 s，找到 s 中最长的回文子串。
示例 1：
输入：s = "babad"
输出："bab"
解释："aba" 同样是符合题意的答案。
示例 2：
输入：s = "cbbd"
输出："bb"
提示：
1 <= s.length <= 1000
s 仅由数字和英文字母组成
# %/


// 暴力算法
// 思路简单但会超时
class Solution {
public:
    string longestPalindrome(string s) {
        int s_len = s.size();
        int cur_i=0,cur_j=0;           //存储最长子串首位
        
        for(int i=0;i<s_len;i++)       //遍历所有子串
            for(int j=s_len-1;j>i;j--)
                if(isPalindrome(s,i,j))
                    if((j-i)>(cur_j-cur_i))   //如果当前回文子串更长，更新子串
                    {
                         cur_i=i;
                         cur_j=j;
                    }
        return s.substr(s,cur_i,cur_j-cur_i+1);
    }
    
    // 判断是否是回文
    bool isPalindrome(string s,int i,int j)
    {
        for(;i<j;i++,j--)
            if(s[i]!=s[j])
                return false;
        return true;
    }
};




// 中心扩散算法
// 从某一个数开始向两边扩散，判断是否是回文

class Solution {
public:
    pair<int, int> expandAroundCenter(const string& s, int left, int right) {         
        while (left >= 0 && right < s.size() && s[left] == s[right]) {                       // 左数等于右数并且未超过边界，返回这俩数的左右边界。
            --left;
            ++right;
        }
        return {left + 1, right - 1};
    }

    string longestPalindrome(string s) {
        int start = 0, end = 0;
        for (int i = 0; i < s.size(); ++i) {
            auto [left1, right1] = expandAroundCenter(s, i, i);   // 计算奇数的情况
            auto [left2, right2] = expandAroundCenter(s, i, i + 1);  // 计算偶数的情况
            if (right1 - left1 > end - start) {                     // 选择最长的情况作为结果
                start = left1;
                end = right1;
            }
            if (right2 - left2 > end - start) {
                start = left2;
                end = right2;
            }
        }
        return s.substr(start, end - start + 1);
    }
};

# %%
/%
6. Z 字形变换
将一个给定字符串 s 根据给定的行数 numRows ，以从上往下、从左到右进行 Z 字形排列。
比如输入字符串为 "PAYPALISHIRING" 行数为 3 时，排列如下：
P   A   H   N
A P L S I I G
Y   I   R
之后，你的输出需要从左往右逐行读取，产生出一个新的字符串，比如："PAHNAPLSIIGYIR"。
请你实现这个将字符串进行指定行数变换的函数：
string convert(string s, int numRows);
示例 1：
输入：s = "PAYPALISHIRING", numRows = 3
输出："PAHNAPLSIIGYIR"
示例 2：
输入：s = "PAYPALISHIRING", numRows = 4
输出："PINALSIGYAHRPI"
解释：
P     I    N
A   L S  I G
Y A   H R
P     I
示例 3：
输入：s = "A", numRows = 1
输出："A"
# %/

class Solution {
public:
    string convert(string s, int numRows) {
        vector<string> p;
        for(int i=0;i<numRows;i++)         // 创建每一行用来储存Z字结构
            p.push_back("");
        int len = s.size();
        int k = 0;         // 用来计数插入哪行
        int flag = 1 ;     // 用来计数移动到哪行，上移还是下移
        string sum;        // 数组拼接 
        if(numRows==1)     // 只有一行就直接返回了，相当于没做变换
            return s;
        for(int i=0;i<len;i++)           
        {
            if(flag==1)
            {
                p[k]+=s[i];
                k++;
            }
            else
            {
                p[k]+=s[i];
                k--;
            }
            if(k==0||k==numRows-1)
                flag = -flag;
        }
        for(int i=0;i<numRows;i++)
            sum+=p[i];
    return sum;
    }
};

# %%
// 9.回文数
/%
给你一个整数 x ，如果 x 是一个回文整数，返回 true ；否则，返回 false 。

回文数是指正序（从左向右）和倒序（从右向左）读都是一样的整数。

例如，121 是回文，而 123 不是。
 

示例 1：

输入：x = 121
输出：true
示例 2：

输入：x = -121
输出：false
解释：从左向右读, 为 -121 。 从右向左读, 为 121- 。因此它不是一个回文数。
示例 3：

输入：x = 10
输出：false
解释：从右向左读, 为 01 。因此它不是一个回文数。
# %/

class Solution {
public:
    bool isPalindrome(int x) {
        if(x<0)          // 负数肯定不是回文
            return false;
        int num[32];
        int len=0,i=0;
        while(x!=0)      // 造一个相反的数组
        {
            num[i++]=x%10;
            len++;
            x/=10;
        }
        i--;
        for(int k=0;k<len;k++,i--)          //判断是否回文
        {
            if(num[i]!=num[k])
                return false;
        }
        return true;
    }
};

# %%
/*
11. 盛最多水的容器
给定一个长度为 n 的整数数组 height 。有 n 条垂线，第 i 条线的两个端点是 (i, 0) 和 (i, height[i]) 。
找出其中的两条线，使得它们与 x 轴共同构成的容器可以容纳最多的水。
返回容器可以储存的最大水量。
说明：你不能倾斜容器。
*/

//简单暴力算法
class Solution {
public:
    int maxArea(vector<int>& height) {
        int max_area = 0;                          // 储存最大的面积
        for(int i=0;i<height.size();i++)           // 遍历所有情况
        {
            for(int j=i+1;j<height.size();j++)
            { 
                int low_height = height[i]<height[j]?height[i]:height[j];            // 取到两端水桶最低的a高度
                int row = j-i;                                                       // 取到长度
                    if(low_height*row>max_area)                                      // 更新最大面积
                        max_area = low_height*row;                                   
            }
        }
        return max_area;
    }
};

// 双指针算法
/% 
将指针放于首部和尾部。
每次的面积为min(height[i],height[j])*(j-i)
如果每次移动长板,假设i为短板，移动后的j为j-1
min(height[i],height[j])*(j-i) = height[i]*(j-i) 
min(height[i],height[j-1])*(j-i-1) = height[i]*(j-i-1) 或 height[j-1]*(j-i-1)
其中height[i]>height[j-1]
因此hight[i]*[j-i] >height[i]*(j-1-1)>height[j-1]*(j-i-1)
所以移动长板得到的值必定比原来更小
所以每次移动要移动短板，才可能获得比原先更大的值
# %/

class Solution {
public:
    int maxArea(vector<int>& height) {
        int i = 0, j = height.size()-1, max_area=0;
        while(i < j)
        {
            max_area = height[i]<height[j]?
            max(max_area, (j - i)*height[i++]):
            max(max_area, (j - i)*height[j--]);
        }
        return max_area;
    }
};

# %%
/%
12. 整数转罗马数字
罗马数字包含以下七种字符： I， V， X， L，C，D 和 M。

字符          数值
I             1
V             5
X             10
L             50
C             100
D             500
M             1000
例如， 罗马数字 2 写做 II ，即为两个并列的 1。12 写做 XII ，即为 X + II 。 27 写做  XXVII, 即为 XX + V + II 。

通常情况下，罗马数字中小的数字在大的数字的右边。但也存在特例，例如 4 不写做 IIII，而是 IV。数字 1 在数字 5 的左边，所表示的数等于大数 5 减小数 1 得到的数值 4 。同样地，数字 9 表示为 IX。这个特殊的规则只适用于以下六种情况：

I 可以放在 V (5) 和 X (10) 的左边，来表示 4 和 9。
X 可以放在 L (50) 和 C (100) 的左边，来表示 40 和 90。 
C 可以放在 D (500) 和 M (1000) 的左边，来表示 400 和 900。
给你一个整数，将其转为罗马数字。

# %/

// 硬编码解决问题
const string thousands[] = {"", "M", "MM", "MMM"};                                              // 千位
const string hundreds[]  = {"", "C", "CC", "CCC", "CD", "D", "DC", "DCC", "DCCC", "CM"};        // 百位
const string tens[]      = {"", "X", "XX", "XXX", "XL", "L", "LX", "LXX", "LXXX", "XC"};        // 十位
const string ones[]      = {"", "I", "II", "III", "IV", "V", "VI", "VII", "VIII", "IX"};        // 个位

class Solution {
public:
    string intToRoman(int num) {
        return thousands[num / 1000] + hundreds[num % 1000 / 100] + tens[num % 100 / 10] + ones[num % 10];
    }
};

# %%
/%
13. 罗马数字转整数


罗马数字包含以下七种字符： I， V， X， L，C，D 和 M。

字符          数值
I             1
V             5
X             10
L             50
C             100
D             500
M             1000
例如， 罗马数字 2 写做 II ，即为两个并列的 1。12 写做 XII ，即为 X + II 。 27 写做  XXVII, 即为 XX + V + II 。

通常情况下，罗马数字中小的数字在大的数字的右边。但也存在特例，例如 4 不写做 IIII，而是 IV。数字 1 在数字 5 的左边，所表示的数等于大数 5 减小数 1 得到的数值 4 。同样地，数字 9 表示为 IX。这个特殊的规则只适用于以下六种情况：

I 可以放在 V (5) 和 X (10) 的左边，来表示 4 和 9。
X 可以放在 L (50) 和 C (100) 的左边，来表示 40 和 90。 
C 可以放在 D (500) 和 M (1000) 的左边，来表示 400 和 900。
给你一个整数，将其转为罗马数字。

# %/


// 模拟运算解决问题
unordered_map<char, int> value = {
        {'I', 1},
        {'V', 5},
        {'X', 10},
        {'L', 50},
        {'C', 100},
        {'D', 500},
        {'M', 1000},
    };

class Solution {
public:
    int romanToInt(string s) {
        int len = s.size();
        int sum = 0;
        if(len == 1)
            return value[s[0]];
        for(int i=0,j=1;j<=len;i++,j++){
            if(value[s[i]]<value[s[j]]){
                sum += (value[s[j]]-value[s[i]]);
                i++;
                j++;
            }
            else
                sum+= value[s[i]];
        }
        return sum;
    }
};

# %%
/%
14. 最长公共前缀
编写一个函数来查找字符串数组中的最长公共前缀。

如果不存在公共前缀，返回空字符串 ""。

 

示例 1：

输入：strs = ["flower","flow","flight"]
输出："fl"
示例 2：

输入：strs = ["dog","racecar","car"]
输出：""
解释：输入不存在公共前缀。

# %/


// 俩俩公共子串寻找

class Solution {
public:
    string CommonPrefix(string& s1,string& s2){
        int min_lenth = min(s1.size(),s2.size());
        int index = 0;
        while (index < min_lenth && s1[index] == s2[index]) {
            index++;
        }
        return s1.substr(0, index);
    }



    string longestCommonPrefix(vector<string>& strs) {
        int lenth = strs.size();
        string max_string = strs[0];
        if(lenth == 1)
            return strs[0];
        for(int i = 0 ;i<lenth-1;i++){
            max_string = CommonPrefix(max_string,strs[i+1]);
            if(max_string == "")
                return "";
        }
        return max_string;
    }
};

# %%
/%
20. 有效的括号
给定一个只包括 '('，')'，'{'，'}'，'['，']' 的字符串 s ，判断字符串是否有效。

有效字符串需满足：

左括号必须用相同类型的右括号闭合。
左括号必须以正确的顺序闭合。
每个右括号都有一个对应的相同类型的左括号。
 

示例 1：

输入：s = "()"
输出：true
示例 2：

输入：s = "()[]{}"
输出：true
示例 3：

输入：s = "(]"
输出：false

# %/

class Solution {
public:
    bool isValid(string s) {
        int n = s.size();
        if (n % 2 == 1) {
            return false;
        }

        unordered_map<char, char> pairs = {
            {')', '('},
            {']', '['},
            {'}', '{'}
        };
        stack<char> stk;
        for (char ch: s) {
            if (pairs.count(ch)) {
                if (stk.empty() || stk.top() != pairs[ch]) {
                    return false;
                }
                stk.pop();
            }
            else {
                stk.push(ch);
            }
        }
        return stk.empty();
    }
};
